# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
x_view=[202,121,312,514,212,123,454,546]
y_view=[221,421,512,554,312,523,354,246]
z_view=[222,421,316,214,712,623,354,446]
days=range(1,9)

# %%
anime=['Naruto','Luffy','Boruto','Xin','Naruto','Naruto','Naruto','Luffy','Boruto','Boruto','Xin']
anime_Frame=pd.DataFrame(anime,columns=['Char'])
char=anime_Frame['Char'].value_counts()
char
# Out:
# Char
# Naruto    4
# Boruto    3
# Luffy     2
# Xin       2
# Name: count, dtype: int64

# %% [markdown]
# Histogram Digunakan untuk menunjukkan distribusi dari data numerik.

# %%
plt.figure(figsize=(10,4))
plt.hist(anime)
plt.xlabel('CHAR')
plt.ylabel('Jumlah')
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.hist(x_view,bins=5)
plt.xlabel('x')
plt.ylabel('Jumlah')
plt.show()
