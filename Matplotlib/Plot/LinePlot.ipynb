# %%
from matplotlib import pyplot as plt

# %%
x_view=[202,121,312,514,212,123,454,546]
y_view=[221,421,512,554,312,523,354,246]
z_view=[222,421,316,214,712,623,354,446]
days=range(1,9)

# %%
plt.figure(figsize=(10,4))
plt.plot(x_view,label='x')
plt.plot(y_view,label='y')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(x_view,y_view,label='x')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()
