# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
x_view=[202,121,312,514,212,123,454,546]
y_view=[221,421,512,554,312,523,354,246]
z_view=[222,421,316,214,712,623,354,446]
days=range(1,9)

# %%
anime=['Naruto','Luffy','Boruto','Xin','Naruto','Naruto','Naruto','Luffy','Boruto','Boruto','Xin']
anime_Frame=pd.DataFrame(anime,columns=['Char'])
char=anime_Frame['Char'].value_counts()

# %%
plt.figure(figsize=(10,4))
plt.bar(char.index,char.values,label='CHAR')
plt.xlabel('Char Anime')
plt.ylabel('Jumlah')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.bar([a-0.25 for a in days],x_view,label='X',align='edge',width=0.25)
plt.bar([a+0.25 for a in days],y_view,label='Y',align='edge',width=-0.25)
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()
